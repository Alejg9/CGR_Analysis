# %%
from libs.exploration import DataAnalysisEngine

columns = ['tmax(degC)','tmin(degC)','ppt(mm)','ws(mps)','aet(mm)','q(mm)','soil(mm)']
# Example usage:
for col in columns:
    engine = DataAnalysisEngine(
        input_file='./data/CGR.xlsx',
        data_columns=[col],
        output_dir=f'./data/{col}'
    )
    results = engine.analyze()
    print(f"Analysis completed. Results saved to './data/{col}/analysis_results.json'.")
# Out:
# {'date': 0      195801
# 1      195802
# 2      195803
# 3      195804
# 4      195805
#         ...
# 775    202208
# 776    202209
# 777    202210
# 778    202211
# 779    202212
# Name: Fecha, Length: 780, dtype: int64, 'seasonal': 0      0.728389
# 1      1.409494
# 2      1.548664
# 3      0.188462
# 4     -2.413631
#          ...
# 775   -0.608085
# 776    0.120896
# 777    1.319999
# 778    1.145031
# 779    1.437883
# Name: seasonal, Length: 780, dtype: float64, 'trend': 0      29.796597
# 1      29.702639
# 2      29.608681
# 3      29.514722
# 4      29.420764
#          ...
# 775    28.873611
# 776    28.713194
# 777    28.552778
# 778    28.392361
# 779    28.231944
# Name: trend, Length: 780, dtype: float64, 'resid': 0      0.395014
# 1      0.937867
# 2      0.152655
# 3     -0.703185
# 4     -0.407133
#          ...
# 775   -0.665526
# 776   -0.634091
# 777    0.127224
# 778    0.062608
# 779    1.530172
# ...
