# %%
import tensorflow as tf
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    # Restrict TensorFlow to only allocate 1GB of memory on the first GPU
    try:
        tf.config.set_logical_device_configuration(
            gpus[0],
            [tf.config.LogicalDeviceConfiguration(memory_limit=6*1024)])
        logical_gpus = tf.config.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Virtual devices must be set before GPUs have been initialized
        print(e)
# Out:
# 2026-02-18 21:53:03.950124: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 1 Physical GPUs, 1 Logical GPUs
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771451585.749577       8 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6144 MB memory:  -> device: 0, name: AMD Radeon RX 9070 XT, pci bus id: 0000:03:00.0

# %% [markdown]
# # Entrenamiento de la serie completa
#
# En esta sección se entrena la serie de tiempo en sus valores crudos

# %%
# Data processing and model train

from libs.ml import AtmosphericalData
from tensorflow import keras
from keras.src.callbacks import EarlyStopping
from keras.regularizers import l2
def train_model(target_column:str, date_col: str, train_column: str, n_steps:int, training_args: dict, model_args: list, compile_args: dict = None):
    ## Read data and preprocessing

    inside = []
    for v in model_args:
        layer = getattr(keras.layers, v['layer'])

        inside.append(layer(v['units'], **v['args']))

    model = keras.models.Sequential(inside)

    ad = AtmosphericalData(model=model, path=f"./data/{target_column}/{target_column}_decomposition.csv", use_cudnn=False)
    del model

    print(ad.df.columns)

    ad.convert_date(date_col=date_col)
    ad.target_selection(train_column)
    ad.data_preprocessing(n_steps=n_steps, train_vol=0.9)

    ## Train data
    ad.train_data(
        epochs=training_args['epochs'],
        batch_size=training_args['batch_size'],
        validation_split=training_args['validation_split'],
        verbose=training_args['verbose'],
        **compile_args
    )


    ## Test trained model
    ad.test_model()


    ## Plot comparison
    ad.plot_tests()

    return ad

# %%
target = 'ppt(mm)'

# %%
n_steps_r = 3

model_args_r = [
    {'layer': 'Input', 'units': (n_steps_r, 3), 'args': {}},
    {'layer': 'LSTM', 'units':16, 'args': {'return_sequences': False, 'use_cudnn': False}},
    {'layer': 'Dense', 'units': 1, 'args': {}},
]

compile_args_r = {
    'optimizer': 'adam',
    'loss': 'mse',
    'metrics': ['mae'],
}

training_args_r = {
    'epochs': 150,
    'batch_size': 12,
    'validation_split': 0.2,
    'callbacks': [EarlyStopping(patience=20, restore_best_weights=True)],
    'verbose': 1
}

ad_r = train_model(
    target_column=target,
    date_col='date',
    train_column='resid',
    n_steps=n_steps_r,
    training_args=training_args_r,
    model_args=model_args_r,
    compile_args=compile_args_r
)
# Out:
# Index(['date', 'seasonal', 'trend', 'resid', 'observed', 'weights', 'rt'], dtype='object')
# X shape: (777, 3, 3)
# y shape: (777,)
# Epoch 1/150
# 2026-02-18 21:53:15.229495: I external/local_xla/xla/service/service.cc:163] XLA service 0x730e4c005920 initialized for platform ROCM (this does not guarantee that XLA will be used). Devices:
# 2026-02-18 21:53:15.229507: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): AMD Radeon RX 9070 XT, AMDGPU ISA version: gfx1201
# 2026-02-18 21:53:15.246985: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-02-18 21:53:15.361904: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 35/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8964 - mae: 0.7226
# I0000 00:00:1771451596.359477     120 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2026-02-18 21:53:16.566203: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 4s 47ms/step - loss: 0.9963 - mae: 0.7698 - val_loss: 1.3883 - val_mae: 0.9251
# Epoch 2/150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9687 - mae: 0.7587 - val_loss: 1.3636 - val_mae: 0.9143
# Epoch 3/150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9531 - mae: 0.7542 - val_loss: 1.3509 - val_mae: 0.9083
# Epoch 4/150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9444 - mae: 0.7501 - val_loss: 1.3445 - val_mae: 0.9035
# Epoch 5/150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9380 - mae: 0.7476 - val_loss: 1.3424 - val_mae: 0.9026
# Epoch 6/150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9348 - mae: 0.7469 - val_loss: 1.3375 - val_mae: 0.8992
# Epoch 7/150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.
150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7920 - mae: 0.6918 - val_loss: 1.4659 - val_mae: 0.9188
# Epoch 143/150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7959 - mae: 0.6976 - val_loss: 1.4624 - val_mae: 0.9196
# Epoch 144/150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7847 - mae: 0.6904 - val_loss: 1.4649 - val_mae: 0.9182
# Epoch 145/150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7877 - mae: 0.6890 - val_loss: 1.4653 - val_mae: 0.9187
# Epoch 146/150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7869 - mae: 0.6910 - val_loss: 1.4701 - val_mae: 0.9202
# Epoch 147/150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7845 - mae: 0.6898 - val_loss: 1.4713 - val_mae: 0.9200
# Epoch 148/150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7858 - mae: 0.6907 - val_loss: 1.4738 - val_mae: 0.9211
# Epoch 149/150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7876 - mae: 0.6914 - val_loss: 1.4709 - val_mae: 0.9190
# Epoch 150/150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7794 - mae: 0.6881 - val_loss: 1.4751 - val_mae: 0.9204
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step
# %RMSE: 3382.3744540911953
# %MAE: 2580.772792033467

# %%
n_steps_t = 24
model_args_t = [
    {'layer': 'InputLayer', 'units': (n_steps_t, 3), 'args': {}},  # Un solo feature (trend)
    {'layer': 'LSTM', 'units': 128, 'args': {'return_sequences': True, 'use_cudnn':False, 'dropout': 0.0}},
    {'layer': 'LSTM', 'units': 64, 'args': {'return_sequences': False, 'use_cudnn':False, 'dropout': 0.0}},
    {'layer': 'Dense', 'units': 32, 'args': {'activation': 'relu', 'kernel_regularizer': l2(1e-4)}},
    {'layer': 'Dense', 'units': 1, 'args': {}},
]

compile_args_t = {
    'optimizer': 'adam',
    'loss': 'mse',
    'metrics': ['mse'],
}

training_args_t = {
    'epochs': 300,
    'batch_size': 32,
    'validation_split': 0.15,
    'callbacks': [EarlyStopping(patience=30, restore_best_weights=True)],
    'verbose': 1,
}

ad_t = train_model(
    target_column=target,
    date_col='date',
    train_column='trend',
    n_steps=n_steps_t,
    training_args=training_args_t,
    model_args=model_args_t,
    compile_args=compile_args_t
)
# Out:
# Index(['date', 'seasonal', 'trend', 'resid', 'observed', 'weights', 'rt'], dtype='object')
# X shape: (756, 24, 3)
# y shape: (756,)
# Epoch 1/300
# 2026-02-18 21:53:37.896643: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-18 21:53:37.896660: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-18 21:53:37.896675: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-18 21:53:37.896683: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 17/19 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4920 - mse: 0.4878
# 2026-02-18 21:53:41.273893: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-02-18 21:53:41.273912: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step - loss: 0.4836 - mse: 0.4793
# 2026-02-18 21:53:45.085809: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 9s 287ms/step - loss: 0.4113 - mse: 0.4071 - val_loss: 0.4066 - val_mse: 0.4023
# Epoch 2/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2021 - mse: 0.1978 - val_loss: 0.2105 - val_mse: 0.2062
# Epoch 3/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1582 - mse: 0.1539 - val_loss: 0.1629 - val_mse: 0.1585
# Epoch 4/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1163 - mse: 0.1119 - val_loss: 0.1271 - val_mse: 0.1228
# Epoch 5/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1063 - mse: 0.1019 - val_loss: 0.1149 - val_mse: 0.1105
# Epoch 6/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1045 - mse: 0.1002 - val_loss: 0.1820 - val_mse: 0.1777
# Epoch 7/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1325 - mse: 0.1282 - val_loss: 0.1420 - val_mse: 0.1377
# Epoch 8/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1013 - mse: 0.0970 - val_loss: 0.1019 - val_mse: 0.0976
# Epoch 9/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0897 - mse: 0.0855 - val_loss: 0.0928 - val_mse: 0.0886
# Epoch 10/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0837 - mse: 0.0794 - val_loss: 0.0845 - val_mse: 0.0802
# Epoch 11/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0801 - mse: 0.0759 - val_loss: 0.0867 - val_mse: 0.0825
# Epoch 12/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.
300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0169 - mse: 0.0148 - val_loss: 0.0689 - val_mse: 0.0668
# Epoch 183/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0173 - mse: 0.0151 - val_loss: 0.0556 - val_mse: 0.0535
# Epoch 184/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0185 - mse: 0.0163 - val_loss: 0.0540 - val_mse: 0.0519
# Epoch 185/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0158 - mse: 0.0137 - val_loss: 0.0597 - val_mse: 0.0576
# Epoch 186/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0197 - mse: 0.0175 - val_loss: 0.0572 - val_mse: 0.0551
# Epoch 187/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0165 - mse: 0.0144 - val_loss: 0.0509 - val_mse: 0.0487
# Epoch 188/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0153 - mse: 0.0131 - val_loss: 0.0646 - val_mse: 0.0625
# Epoch 189/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0143 - mse: 0.0122 - val_loss: 0.0721 - val_mse: 0.0700
# Epoch 190/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0166 - mse: 0.0145 - val_loss: 0.0544 - val_mse: 0.0523
# Epoch 191/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0155 - mse: 0.0133 - val_loss: 0.0622 - val_mse: 0.0601
# Epoch 192/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0135 - mse: 0.0114 - val_loss: 0.0615 - val_mse: 0.0594
# Epoch 193/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0137 - mse: 0.0116 - val_loss: 0.0636 - val_mse: 0.0615
# Epoch 194/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0135 - mse: 0.0114 - val_loss: 0.0763 - val_mse: 0.0742
# Epoch 195/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0146 - mse: 0.0125 - val_loss: 0.0745 - val_mse: 0.0724
# Epoch 196/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0120 - mse: 0.0100 - val_loss: 0.0696 - val_mse: 0.0675
# Epoch 197/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0114 - mse: 0.0094 - val_loss: 0.0683 - val_mse: 0.0662
# Epoch 198/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0145 - mse: 0.0124 - val_loss: 0.0780 - val_mse: 0.0759
# Epoch 199/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0135 - mse: 0.0114 - val_loss: 0.0616 - val_mse: 0.0596
# Epoch 200/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0125 - mse: 0.0104 - val_loss: 0.0720 - val_mse: 0.0700
# Epoch 201/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0118 - mse: 0.0098 - val_loss: 0.0736 - val_mse: 0.0715
# Epoch 202/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0132 - mse: 0.0112 - val_loss: 0.0668 - val_mse: 0.0647
# Epoch 203/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0151 - mse: 0.0130 - val_loss: 0.0681 - val_mse: 0.0660
# Epoch 204/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0110 - mse: 0.0090 - val_loss: 0.0784 - val_mse: 0.0764
# Epoch 205/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0118 - mse: 0.0098 - val_loss: 0.0745 - val_mse: 0.0724
# Epoch 206/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0118 - mse: 0.0098 - val_loss: 0.0789 - val_mse: 0.0769
# Epoch 207/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0111 - mse: 0.0091 - val_loss: 0.0877 - val_mse: 0.0857
# Epoch 208/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0130 - mse: 0.0110 - val_loss: 0.0637 - val_mse: 0.0617
# Epoch 209/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0133 - mse: 0.0113 - val_loss: 0.0995 - val_mse: 0.0975
# Epoch 210/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0113 - mse: 0.0093 - val_loss: 0.0858 - val_mse: 0.0838
# Epoch 211/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0101 - mse: 0.0081 - val_loss: 0.0924 - val_mse: 0.0904
# Epoch 212/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0098 - mse: 0.0078 - val_loss: 0.0860 - val_mse: 0.0840
# Epoch 213/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0105 - mse: 0.0085 - val_loss: 0.0916 - val_mse: 0.0897
# Epoch 214/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0094 - mse: 0.0075 - val_loss: 0.0976 - val_mse: 0.0956
# Epoch 215/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0082 - mse: 0.0062 - val_loss: 0.0965 - val_mse: 0.0946
# Epoch 216/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.
300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0132 - mse: 0.0114 - val_loss: 0.1174 - val_mse: 0.1157
# Epoch 252/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0088 - mse: 0.0071 - val_loss: 0.1209 - val_mse: 0.1192
# Epoch 253/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0065 - mse: 0.0048 - val_loss: 0.1133 - val_mse: 0.1116
# Epoch 254/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0063 - mse: 0.0046 - val_loss: 0.1179 - val_mse: 0.1161
# Epoch 255/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0065 - mse: 0.0048 - val_loss: 0.1222 - val_mse: 0.1205
# Epoch 256/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0059 - mse: 0.0043 - val_loss: 0.1240 - val_mse: 0.1223
# Epoch 257/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0060 - mse: 0.0043 - val_loss: 0.1129 - val_mse: 0.1113
# Epoch 258/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0065 - mse: 0.0048 - val_loss: 0.1116 - val_mse: 0.1099
# Epoch 259/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0049 - mse: 0.0032 - val_loss: 0.1208 - val_mse: 0.1191
# Epoch 260/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0041 - mse: 0.0025 - val_loss: 0.1170 - val_mse: 0.1153
# Epoch 261/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0039 - mse: 0.0023 - val_loss: 0.1187 - val_mse: 0.1171
# Epoch 262/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0038 - mse: 0.0022 - val_loss: 0.1244 - val_mse: 0.1228
# Epoch 263/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0037 - mse: 0.0020 - val_loss: 0.1208 - val_mse: 0.1191
# Epoch 264/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0040 - mse: 0.0024 - val_loss: 0.1262 - val_mse: 0.1245
# Epoch 265/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0040 - mse: 0.0023 - val_loss: 0.1304 - val_mse: 0.1288
# Epoch 266/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0037 - mse: 0.0020 - val_loss: 0.1311 - val_mse: 0.1295
# Epoch 267/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0035 - mse: 0.0019 - val_loss: 0.1327 - val_mse: 0.1310
# Epoch 268/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0043 - mse: 0.0026 - val_loss: 0.1251 - val_mse: 0.1235
# Epoch 269/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0046 - mse: 0.0030 - val_loss: 0.1355 - val_mse: 0.1339
# Epoch 270/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0082 - mse: 0.0066 - val_loss: 0.1236 - val_mse: 0.1220
# Epoch 271/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0063 - mse: 0.0047 - val_loss: 0.1321 - val_mse: 0.1305
# Epoch 272/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0057 - mse: 0.0041 - val_loss: 0.1258 - val_mse: 0.1242
# Epoch 273/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0086 - mse: 0.0070 - val_loss: 0.1272 - val_mse: 0.1256
# Epoch 274/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0072 - mse: 0.0056 - val_loss: 0.1232 - val_mse: 0.1217
# Epoch 275/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0058 - mse: 0.0042 - val_loss: 0.1350 - val_mse: 0.1334
# Epoch 276/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0068 - mse: 0.0052 - val_loss: 0.1270 - val_mse: 0.1255
# Epoch 277/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0059 - mse: 0.0044 - val_loss: 0.1243 - val_mse: 0.1227
# Epoch 278/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0058 - mse: 0.0042 - val_loss: 0.1252 - val_mse: 0.1236
# Epoch 279/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0055 - mse: 0.0039 - val_loss: 0.1297 - val_mse: 0.1282
# Epoch 280/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0053 - mse: 0.0037 - val_loss: 0.1355 - val_mse: 0.1339
# Epoch 281/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0058 - mse: 0.0043 - val_loss: 0.1173 - val_mse: 0.1158
# Epoch 282/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0080 - mse: 0.0065 - val_loss: 0.1156 - val_mse: 0.1140
# Epoch 283/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0061 - mse: 0.0045 - val_loss: 0.1272 - val_mse: 0.1257
# Epoch 284/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0043 - mse: 0.0027 - val_loss: 0.1274 - val_mse: 0.1259
# Epoch 285/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0047 - mse: 0.0032 - val_loss: 0.1319 - val_mse: 0.1304
# Epoch 286/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0038 - mse: 0.0023 - val_loss: 0.1345 - val_mse: 0.1330
# Epoch 287/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0050 - mse: 0.0034 - val_loss: 0.1367 - val_mse: 0.1352
# Epoch 288/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0064 - mse: 0.0049 - val_loss: 0.1265 - val_mse: 0.1250
# Epoch 289/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0045 - mse: 0.0030 - val_loss: 0.1355 - val_mse: 0.1340
# Epoch 290/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0041 - mse: 0.0026 - val_loss: 0.1300 - val_mse: 0.1285
# Epoch 291/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0052 - mse: 0.0037 - val_loss: 0.1294 - val_mse: 0.1279
# Epoch 292/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0038 - mse: 0.0023 - val_loss: 0.1330 - val_mse: 0.1315
# Epoch 293/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0037 - mse: 0.0022 - val_loss: 0.1369 - val_mse: 0.1355
# Epoch 294/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0033 - mse: 0.0018 - val_loss: 0.1272 - val_mse: 0.1257
# Epoch 295/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0031 - mse: 0.0016 - val_loss: 0.1398 - val_mse: 0.1383
# Epoch 296/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0028 - mse: 0.0013 - val_loss: 0.1373 - val_mse: 0.1359
# Epoch 297/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0025 - mse: 0.0010 - val_loss: 0.1365 - val_mse: 0.1350
# Epoch 298/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0026 - mse: 0.0011 - val_loss: 0.1385 - val_mse: 0.1370
# Epoch 299/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0025 - mse: 0.0010 - val_loss: 0.1446 - val_mse: 0.1432
# Epoch 300/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0026 - mse: 0.0012 - val_loss: 0.1393 - val_mse: 0.1378
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 1s 796ms/step
# 2026-02-18 21:54:40.250939: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 576ms/step
# %RMSE: 753.196908582424
# %MAE: 614.7081247965707

# %%
n_steps_s = 12

model_args_s = [
    {'layer': 'Input', 'units': (n_steps_s, 3), 'args': {}},
    {'layer': 'LSTM', 'units':32, 'args': {'return_sequences': True, 'use_cudnn': False}},
    {'layer': 'LSTM', 'units':16, 'args': {'return_sequences': False, 'use_cudnn': False}},
    {'layer': 'Dense', 'units': 1, 'args': {}},
]

compile_args_s = {
    'optimizer': 'adam',
    'loss': 'mse',
    'metrics': ['mse'],
}

training_args_s = {
    'epochs': 150,
    'batch_size': 16,
    'validation_split': 0.15,
    'callbacks': [EarlyStopping(patience=20, restore_best_weights=True)],
    'verbose': 1
}

ad_s = train_model(
    target_column=target,
    date_col='date',
    train_column='seasonal',
    n_steps=n_steps_s,
    training_args=training_args_s,
    model_args=model_args_s,
    compile_args=compile_args_s
)
# Out:
# Index(['date', 'seasonal', 'trend', 'resid', 'observed', 'weights', 'rt'], dtype='object')
# X shape: (768, 12, 3)
# y shape: (768,)
# Epoch 1/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 5s 68ms/step - loss: 0.7758 - mse: 0.7758 - val_loss: 0.3846 - val_mse: 0.3846
# Epoch 2/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1529 - mse: 0.1529 - val_loss: 0.0954 - val_mse: 0.0954
# Epoch 3/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0894 - mse: 0.0894 - val_loss: 0.0740 - val_mse: 0.0740
# Epoch 4/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0722 - mse: 0.0722 - val_loss: 0.0618 - val_mse: 0.0618
# Epoch 5/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0605 - mse: 0.0605 - val_loss: 0.0543 - val_mse: 0.0543
# Epoch 6/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0520 - mse: 0.0520 - val_loss: 0.0624 - val_mse: 0.0624
# Epoch 7/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0540 - mse: 0.0540 - val_loss: 0.0458 - val_mse: 0.0458
# Epoch 8/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0397 - mse: 0.0397 - val_loss: 0.0344 - val_mse: 0.0344
# Epoch 9/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0335 - mse: 0.0335 - val_loss: 0.0284 - val_mse: 0.0284
# Epoch 10/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0276 - mse: 0.0276 - val_loss: 0.0251 - val_mse: 0.0251
# Epoch 11/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0245 - mse: 0.0245 - val_loss: 0.0197 - val_mse: 0.0197
# Epoch 12/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0177 - mse: 0.0177 - val_loss: 0.0152 - val_mse: 0.0152
# Epoch 13/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0136 - mse: 0.0136 - val_loss: 0.0126 - val_mse: 0.0126
# Epoch 14/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0110 - val_mse: 0.0110
# Epoch 15/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0095 - val_mse: 0.0095
# Epoch 16/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0081 - val_mse: 0.0081
# Epoch 17/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0071 - mse: 0.0071 - val_loss: 0.0063 - val_mse: 0.0063
# Epoch 18/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0056 - mse: 0.0056 - val_loss: 0.0050 - val_mse: 0.0050
# Epoch 19/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0038 - val_mse: 0.0038
# Epoch 20/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0030 - val_mse: 0.0030
# Epoch 21/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0023 - val_mse: 0.0023
# Epoch 22/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0019 - val_mse: 0.0019
# Epoch 23/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 24/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0016 - val_mse: 0.0016
# Epoch 25/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0010 - val_mse: 0.0010
# Epoch 26/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.
150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1233e-14 - mse: 1.1233e-14 - val_loss: 8.9485e-15 - val_mse: 8.9485e-15
# Epoch 137/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0068e-14 - mse: 1.0068e-14 - val_loss: 3.2016e-14 - val_mse: 3.2016e-14
# Epoch 138/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.3999e-12 - mse: 7.3999e-12 - val_loss: 7.6271e-11 - val_mse: 7.6271e-11
# Epoch 139/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.3739e-09 - mse: 7.3739e-09 - val_loss: 2.6086e-08 - val_mse: 2.6086e-08
# Epoch 140/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.0367e-07 - mse: 3.0367e-07 - val_loss: 3.2097e-06 - val_mse: 3.2097e-06
# Epoch 141/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.3296e-04 - mse: 4.3296e-04 - val_loss: 0.0013 - val_mse: 0.0013
# Epoch 142/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.0306e-04 - mse: 6.0306e-04 - val_loss: 7.1168e-05 - val_mse: 7.1168e-05
# Epoch 143/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.2378e-05 - mse: 5.2378e-05 - val_loss: 3.5457e-05 - val_mse: 3.5457e-05
# Epoch 144/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.8591e-05 - mse: 3.8591e-05 - val_loss: 1.0917e-05 - val_mse: 1.0917e-05
# Epoch 145/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.9438e-05 - mse: 5.9438e-05 - val_loss: 6.4784e-05 - val_mse: 6.4784e-05
# Epoch 146/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6180e-04 - mse: 1.6180e-04 - val_loss: 5.6062e-04 - val_mse: 5.6062e-04
# Epoch 147/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.3523e-04 - mse: 2.3523e-04 - val_loss: 7.5858e-05 - val_mse: 7.5858e-05
# Epoch 148/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 3.2991e-05 - mse: 3.2991e-05 - val_loss: 9.3353e-07 - val_mse: 9.3353e-07
# Epoch 149/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9999e-06 - mse: 1.9999e-06 - val_loss: 1.8505e-06 - val_mse: 1.8505e-06
# Epoch 150/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.3392e-05 - mse: 1.3392e-05 - val_loss: 1.3154e-05 - val_mse: 1.3154e-05
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x730f103f7b50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 1s 590ms/stepWARNING:tensorflow:6 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x730f103f7b50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 263ms/step
# %RMSE: 25.101646417392733
# %MAE: 18.66745152146681

# %%
n_steps_o = 24

model_args_o = [
    {'layer': 'Input', 'units': (n_steps_o, 3), 'args': {}},
    {'layer': 'LSTM', 'units':32, 'args': {'return_sequences': False, 'use_cudnn': False}},
    {'layer': 'Dense', 'units': 1, 'args': {}},
]

compile_args_o = {
    'optimizer': 'adam',
    'loss': 'mse',
    'metrics': ['mse'],
}

training_args_o = {
    'epochs': 150,
    'batch_size': 24,
    'validation_split': 0.1,
    'callbacks': [EarlyStopping(patience=20, restore_best_weights=True)],
    'verbose': 0
}

ad_o = train_model(
    target_column=target,
    date_col='date',
    train_column='observed',
    n_steps=n_steps_o,
    training_args=training_args_o,
    model_args=model_args_o,
    compile_args=compile_args_o
)
# Out:
# Index(['date', 'seasonal', 'trend', 'resid', 'observed', 'weights', 'rt'], dtype='object')
# X shape: (756, 24, 3)
# y shape: (756,)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# %RMSE: 5158.9589469261
# %MAE: 3861.064292506167

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

series = ad_o.df.set_index('date')['observed']

# División manual
train = series[:'2016-08']  # hasta diciembre 2020
test = series['2016-09':]   # desde enero 2021

# Ajustar solo con train
model = SARIMAX(series, order=(1,1,1), seasonal_order=(1,1,1,12))
result = model.fit()

# Predecir en conjunto de prueba (in-sample)
start = test.index[0]
end = test.index[-1]
pred_test = result.predict(start=start, end=end)

# Calcular métricas
rmse = np.sqrt(mean_squared_error(test, pred_test))
mae = mean_absolute_error(test, pred_test)
print("%RMSE:", rmse * 100)
print("%MAE:", mae * 100)

# (Opcional) Predecir pasos futuros después de test
# forecast = result.get_forecast(steps=24)
# pred_future = forecast.predicted_mean
# pred_ci = forecast.conf_int()

# Graficar
plt.figure(figsize=(12,6))
plt.plot(pred_test.index, test, label='Real')
plt.plot(pred_test.index, pred_test, label='Predicción Test')
plt.legend()
plt.show()


forecast = result.get_forecast(steps=24)
pred_future = forecast.predicted_mean
pred_ci = forecast.conf_int()


plt.figure(figsize=(12,6))
plt.plot(series.index, series, label='Real')
plt.plot(pred_future.index, pred_future.values, label='Forecast', color='green')
plt.title(f"ARIMA Forecast {forecast_steps} pasos")
plt.legend()
plt.grid()
plt.show()
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.46037D+00    |proj g|=  8.70097D-02
# /usr/local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# At iterate    5    f=  5.39485D+00    |proj g|=  6.24758D-02
#
# At iterate   10    f=  5.32919D+00    |proj g|=  8.85051D-02
#
# At iterate   15    f=  5.26163D+00    |proj g|=  6.16260D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     19     26      1     0     0   3.676D-05   5.262D+00
#   F =   5.2615912467991235
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# %RMSE: 4489.0795213636575
# %MAE: 3240.424729009537
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 48
#      46 plt.plot(series.index, series, label='Real')
#      47 plt.plot(pred_future.index, pred_future.values, label='Forecast', color='green')
# ---> 48 plt.title(f"ARIMA Forecast {forecast_steps} pasos")
#      49 plt.legend()
#      50 plt.grid()
#
# NameError: name 'forecast_steps' is not defined

# %%
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Tu serie mensual
series = ad_o.df.set_index('date')['observed']

# División manual en train/test
train = series[:'2016-08']
test = series['2016-09':]

# Ajustar modelo ARIMA solo con train
# order = (p,d,q) -> ajusta según ACF/PACF o prueba heurística
model = ARIMA(series, order=(1,1,1))
result = model.fit()

# Predicción en el conjunto de prueba
pred_test = result.predict(start=test.index[0], end=test.index[-1], dynamic=False)

# Métricas
rmse = np.sqrt(mean_squared_error(test, pred_test))
mae = mean_absolute_error(test, pred_test)
print("%RMSE:", rmse * 100)
print("%MAE:", mae * 100)

# Graficar real vs predicción test
plt.figure(figsize=(12,6))
plt.plot(pred_test.index, test, label='Real')
plt.plot(pred_test.index, pred_test, label='Predicción Test', color='red')
plt.title("Predicción ARIMA Test")
plt.xlabel("Fecha")
plt.ylabel('Valor')
plt.legend()
plt.grid()
plt.show()

# Predicción de pasos futuros (out-of-sample)
forecast_steps = 24
forecast = result.get_forecast(steps=forecast_steps)
pred_future = forecast.predicted_mean
pred_ci = forecast.conf_int()

plt.figure(figsize=(12,6))
plt.plot(series.index, series, label='Real')
plt.plot(pred_future.index, pred_future.values, label='Forecast', color='green')
plt.title(f"ARIMA Forecast {forecast_steps} pasos")
plt.legend()
plt.grid()
plt.show()

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt

# Tomar la longitud mínima entre los arrays para que coincidan
min_len = min(
    len(ad_r._true_rescaled),
    len(ad_t._true_rescaled),
    len(ad_s._true_rescaled),
    len(pred_test.values)
)

# Convertir todo a 1D
r_true = ad_r._true_rescaled[-min_len:].flatten()
t_true = ad_t._true_rescaled[-min_len:].flatten()
s_true = ad_s._true_rescaled[-min_len:].flatten()

s_pred = ad_s._pred_rescaled[-min_len:].flatten()
t_pred = ad_t._pred_rescaled[-min_len:].flatten()
r_pred = pred_test.values[-min_len:].flatten()  # SARIMA trend o residual según tu modelo

# Sumar elemento a elemento
true_rescaled = r_true + t_true + s_true
pred_rescaled = r_pred + t_pred + s_pred

# Calcular métricas
rmse = np.sqrt(mean_squared_error(true_rescaled, pred_rescaled))
mae = mean_absolute_error(true_rescaled, pred_rescaled)
print("%RMSE:", rmse * 100)
print("%MAE:", mae * 100)

# Fechas
dates = ad_t._test_dates[-min_len:]

# Graficar
plt.figure(figsize=(14,5))
plt.plot(dates, true_rescaled, label="Real", alpha=0.5)
plt.plot(dates, pred_rescaled, label="Predicción", color="red", linewidth=2)
plt.title("Predicción LSTM + SARIMA (Trend + Seasonal + Residual)")
plt.xlabel(ad_t._date_col)
plt.ylabel(ad_t._target_col)
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Encontrar la longitud mínima entre las predicciones verdaderas de los modelos
min_len = min(
    len(ad_r._true_rescaled),
    len(ad_t._true_rescaled),
    len(ad_s._true_rescaled)
)

# Recortar las verdaderas y predichas para que tengan la misma longitud (solo trend + seasonal)
true_rescaled = (
    ad_t._true_rescaled[-min_len:]
    + ad_s._true_rescaled[-min_len:]
    + ad_r._true_rescaled[-min_len:]
)

pred_rescaled = (
    ad_t._pred_rescaled[-min_len:]
    + ad_s._pred_rescaled[-min_len:]
    + ad_r._pred_rescaled[-min_len:]
)

# Aplanar los arrays para matplotlib
true_rescaled = true_rescaled.flatten()
pred_rescaled = pred_rescaled.flatten()

# Calcular métricas
rmse = np.sqrt(mean_squared_error(true_rescaled, pred_rescaled))
mae = mean_absolute_error(true_rescaled, pred_rescaled)
print("%RMSE:", rmse * 100)
print("%MAE:", mae * 100)

# Usar las fechas del modelo trend para el eje x, recortadas al mismo rango
dates = ad_t._test_dates[-min_len:]

# Graficar
plt.figure(figsize=(14,5))
plt.plot(dates, true_rescaled, label="Real", alpha=0.5)
plt.plot(dates, pred_rescaled, label="Predicción", color="red", linewidth=2)
plt.title("Predicción LSTM (Trend + Seasonal)")
plt.xlabel(ad_t._date_col)
plt.ylabel(ad_t._target_col)
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
def build_dates(year):
    return [f'{year}{month}01' if month >= 10 else f'{year}0{month}01' for month in range(1, 13)]
dates_input = build_dates(2023)
dates_input = dates_input + build_dates(2024)
predicts = []
predicts1 = []
for date in dates_input:
    _predict = ad_r.predict_for_date(date)
    _predict += ad_t.predict_for_date(date)
    _predict += ad_s.predict_for_date(date)
    predicts.append(_predict)

    _predict = ad_o.predict_for_date(date)
    predicts1.append(_predict)

forecast = result.get_forecast(steps=24)
pred_future = forecast.predicted_mean.values
pred_ci = forecast.conf_int()
plt.figure(figsize=(14,5))
plt.plot(pd.to_datetime(dates_input, format='%Y%m%d'), predicts, label="Predict S+T+R", color='white', linewidth=2)
plt.plot(pd.to_datetime(dates_input, format='%Y%m%d'), predicts1, label="Predict Obs", color='green', linewidth=1)
plt.plot(pd.to_datetime(dates_input, format='%Y%m%d'), pred_future, label="SARIMA", color='red', linewidth=3)
#plt.plot(ad_r.df['date'], ad_r.df['observed'], label="Real", color="red", linewidth=2)
plt.title("Predicción LSTM de " + target)
plt.xlabel("Fecha")
plt.ylabel(target)
plt.legend()
plt.grid()
plt.tight_layout()
