# %%
import tensorflow as tf
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    # Restrict TensorFlow to only allocate 1GB of memory on the first GPU
    try:
        tf.config.set_logical_device_configuration(
            gpus[0],
            [tf.config.LogicalDeviceConfiguration(memory_limit=6*1024)])
        logical_gpus = tf.config.list_logical_devices('GPU')
        print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
    except RuntimeError as e:
        # Virtual devices must be set before GPUs have been initialized
        print(e)
# Out:
# 2026-01-26 03:05:17.628420: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 1 Physical GPUs, 1 Logical GPUs
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1769396719.047923  796015 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6144 MB memory:  -> device: 0, name: AMD Radeon RX 9070 XT, pci bus id: 0000:03:00.0

# %%
# Data processing and model train

from libs.ml import AtmosphericalData
from tensorflow import keras
from keras.src.callbacks import EarlyStopping
from keras.regularizers import l2
def train_model(target_column:str, date_col: str, train_column: str, n_steps:int, training_args: dict, model_args: list, compile_args: dict = None):
    ## Read data and preprocessing

    inside = []
    for v in model_args:
        layer = getattr(keras.layers, v['layer'])

        inside.append(layer(v['units'], **v['args']))

    model = keras.models.Sequential(inside)

    ad = AtmosphericalData(model=model, path=f"./data/{target_column}/{target_column}_decomposition.csv", use_cudnn=False)
    del model

    print(ad.df.columns)

    ad.convert_date(date_col=date_col)
    ad.target_selection(train_column)
    ad.data_preprocessing(n_steps=n_steps, train_vol=0.9)

    ## Train data
    ad.train_data(
        epochs=training_args['epochs'],
        batch_size=training_args['batch_size'],
        validation_split=training_args['validation_split'],
        verbose=training_args['verbose'],
        **compile_args
    )


    ## Test trained model
    ad.test_model()


    ## Plot comparison
    ad.plot_tests()

    return ad

# %%
target = 'ppt(mm)'

# %%
n_steps_r = 3

model_args_r = [
    {'layer': 'Input', 'units': (n_steps_r, 3), 'args': {}},
    {'layer': 'LSTM', 'units':16, 'args': {'return_sequences': False, 'use_cudnn': False}},
    {'layer': 'Dense', 'units': 1, 'args': {}},
]

compile_args_r = {
    'optimizer': 'adam',
    'loss': 'mse',
    'metrics': ['mae'],
}

training_args_r = {
    'epochs': 150,
    'batch_size': 12,
    'validation_split': 0.2,
    'callbacks': [EarlyStopping(patience=20, restore_best_weights=True)],
    'verbose': 1
}

ad_r = train_model(
    target_column=target,
    date_col='date',
    train_column='resid',
    n_steps=n_steps_r,
    training_args=training_args_r,
    model_args=model_args_r,
    compile_args=compile_args_r
)
# Out:
# Index(['date', 'seasonal', 'trend', 'resid', 'observed', 'weights', 'rt'], dtype='object')
# X shape: (777, 3, 3)
# y shape: (777,)
# Epoch 1/150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 0.9801 - mae: 0.7638 - val_loss: 1.3729 - val_mae: 0.9211
# Epoch 2/150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9567 - mae: 0.7539 - val_loss: 1.3547 - val_mae: 0.9128
# Epoch 3/150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9437 - mae: 0.7486 - val_loss: 1.3462 - val_mae: 0.9059
# Epoch 4/150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9356 - mae: 0.7447 - val_loss: 1.3432 - val_mae: 0.9005
# Epoch 5/150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9326 - mae: 0.7432 - val_loss: 1.3416 - val_mae: 0.8978
# Epoch 6/150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9306 - mae: 0.7432 - val_loss: 1.3414 - val_mae: 0.8991
# Epoch 7/150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9299 - mae: 0.7430 - val_loss: 1.3404 - val_mae: 0.8960
# Epoch 8/150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9285 - mae: 0.7427 - val_loss: 1.3401 - val_mae: 0.8960
# Epoch 9/150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9288 - mae: 0.7408 - val_loss: 1.3411 - val_mae: 0.8947
# Epoch 10/150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9282 - mae: 0.7429 - val_loss: 1.3413 - val_mae: 0.8955
# Epoch 11/150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9267 - mae: 0.7413 - val_loss: 1.3410 - val_mae: 0.8942
# Epoch 12/150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.
150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8071 - mae: 0.6980 - val_loss: 1.4109 - val_mae: 0.9021
# Epoch 145/150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8083 - mae: 0.6984 - val_loss: 1.4105 - val_mae: 0.9027
# Epoch 146/150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8045 - mae: 0.6988 - val_loss: 1.4130 - val_mae: 0.9045
# Epoch 147/150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8057 - mae: 0.6981 - val_loss: 1.4083 - val_mae: 0.9020
# Epoch 148/150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8032 - mae: 0.6963 - val_loss: 1.4099 - val_mae: 0.9011
# Epoch 149/150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8030 - mae: 0.6987 - val_loss: 1.4113 - val_mae: 0.9034
# Epoch 150/150
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8039 - mae: 0.6999 - val_loss: 1.4102 - val_mae: 0.9022
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# %RMSE: 3206.902047549714
# %MAE: 2454.5630386281987

# %%
n_steps_t = 24
model_args_t = [
    {'layer': 'InputLayer', 'units': (n_steps_t, 3), 'args': {}},  # Un solo feature (trend)
    {'layer': 'LSTM', 'units': 128, 'args': {'return_sequences': True, 'use_cudnn':False, 'dropout': 0.0}},
    {'layer': 'LSTM', 'units': 64, 'args': {'return_sequences': False, 'use_cudnn':False, 'dropout': 0.0}},
    {'layer': 'Dense', 'units': 32, 'args': {'activation': 'relu', 'kernel_regularizer': l2(1e-4)}},
    {'layer': 'Dense', 'units': 1, 'args': {}},
]

compile_args_t = {
    'optimizer': 'adam',
    'loss': 'mse',
    'metrics': ['mse'],
}

training_args_t = {
    'epochs': 300,
    'batch_size': 32,
    'validation_split': 0.15,
    'callbacks': [EarlyStopping(patience=30, restore_best_weights=True)],
    'verbose': 1,
}

ad_t = train_model(
    target_column=target,
    date_col='date',
    train_column='trend',
    n_steps=n_steps_t,
    training_args=training_args_t,
    model_args=model_args_t,
    compile_args=compile_args_t
)
# Out:
# Index(['date', 'seasonal', 'trend', 'resid', 'observed', 'weights', 'rt'], dtype='object')
# X shape: (756, 24, 3)
# y shape: (756,)
# Epoch 1/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 6s 179ms/step - loss: 0.4495 - mse: 0.4452 - val_loss: 0.4595 - val_mse: 0.4552
# Epoch 2/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2326 - mse: 0.2283 - val_loss: 0.2513 - val_mse: 0.2469
# Epoch 3/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1602 - mse: 0.1559 - val_loss: 0.1868 - val_mse: 0.1825
# Epoch 4/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1260 - mse: 0.1217 - val_loss: 0.1416 - val_mse: 0.1372
# Epoch 5/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1186 - mse: 0.1143 - val_loss: 0.1182 - val_mse: 0.1139
# Epoch 6/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1008 - mse: 0.0965 - val_loss: 0.1129 - val_mse: 0.1087
# Epoch 7/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1105 - mse: 0.1062 - val_loss: 0.0960 - val_mse: 0.0917
# Epoch 8/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0961 - mse: 0.0919 - val_loss: 0.0905 - val_mse: 0.0863
# Epoch 9/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0825 - mse: 0.0783 - val_loss: 0.1160 - val_mse: 0.1118
# Epoch 10/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0808 - mse: 0.0767 - val_loss: 0.0809 - val_mse: 0.0768
# Epoch 11/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0705 - mse: 0.0664 - val_loss: 0.0625 - val_mse: 0.0583
# Epoch 12/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0622 - mse: 0.0581 - val_loss: 0.0619 - val_mse: 0.0578
# Epoch 13/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0533 - mse: 0.0492 - val_loss: 0.0427 - val_mse: 0.0386
# Epoch 14/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0498 - mse: 0.0457 - val_loss: 0.0442 - val_mse: 0.0401
# Epoch 15/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0488 - mse: 0.0448 - val_loss: 0.1128 - val_mse: 0.1088
# Epoch 16/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.
300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0198 - mse: 0.0175 - val_loss: 0.0533 - val_mse: 0.0510
# Epoch 150/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0205 - mse: 0.0182 - val_loss: 0.0583 - val_mse: 0.0560
# Epoch 151/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0214 - mse: 0.0191 - val_loss: 0.0627 - val_mse: 0.0604
# Epoch 152/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0194 - mse: 0.0171 - val_loss: 0.0582 - val_mse: 0.0559
# Epoch 153/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0182 - mse: 0.0159 - val_loss: 0.0806 - val_mse: 0.0784
# Epoch 154/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0201 - mse: 0.0178 - val_loss: 0.0551 - val_mse: 0.0528
# Epoch 155/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0167 - mse: 0.0144 - val_loss: 0.0589 - val_mse: 0.0566
# Epoch 156/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0165 - mse: 0.0142 - val_loss: 0.0676 - val_mse: 0.0653
# Epoch 157/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0167 - mse: 0.0144 - val_loss: 0.0565 - val_mse: 0.0542
# Epoch 158/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0182 - mse: 0.0159 - val_loss: 0.0664 - val_mse: 0.0641
# Epoch 159/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0173 - mse: 0.0151 - val_loss: 0.0570 - val_mse: 0.0547
# Epoch 160/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0176 - mse: 0.0154 - val_loss: 0.0589 - val_mse: 0.0567
# Epoch 161/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0204 - mse: 0.0182 - val_loss: 0.0638 - val_mse: 0.0615
# Epoch 162/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0184 - mse: 0.0162 - val_loss: 0.0640 - val_mse: 0.0618
# Epoch 163/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0175 - mse: 0.0153 - val_loss: 0.0741 - val_mse: 0.0718
# Epoch 164/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0189 - mse: 0.0167 - val_loss: 0.0587 - val_mse: 0.0565
# Epoch 165/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0172 - mse: 0.0150 - val_loss: 0.0674 - val_mse: 0.0652
# Epoch 166/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0247 - mse: 0.0225 - val_loss: 0.0638 - val_mse: 0.0616
# Epoch 167/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0214 - mse: 0.0192 - val_loss: 0.0490 - val_mse: 0.0468
# Epoch 168/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0202 - mse: 0.0180 - val_loss: 0.0597 - val_mse: 0.0576
# Epoch 169/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0193 - mse: 0.0171 - val_loss: 0.0494 - val_mse: 0.0472
# Epoch 170/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0160 - mse: 0.0138 - val_loss: 0.0586 - val_mse: 0.0564
# Epoch 171/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0184 - mse: 0.0162 - val_loss: 0.0581 - val_mse: 0.0560
# Epoch 172/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0174 - mse: 0.0153 - val_loss: 0.0615 - val_mse: 0.0594
# Epoch 173/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0193 - mse: 0.0172 - val_loss: 0.0672 - val_mse: 0.0651
# Epoch 174/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0172 - mse: 0.0150 - val_loss: 0.0679 - val_mse: 0.0657
# Epoch 175/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0160 - mse: 0.0139 - val_loss: 0.0688 - val_mse: 0.0667
# Epoch 176/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0146 - mse: 0.0125 - val_loss: 0.0704 - val_mse: 0.0683
# Epoch 177/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0147 - mse: 0.0126 - val_loss: 0.0704 - val_mse: 0.0683
# Epoch 178/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0143 - mse: 0.0122 - val_loss: 0.0742 - val_mse: 0.0721
# Epoch 179/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0146 - mse: 0.0125 - val_loss: 0.0633 - val_mse: 0.0612
# Epoch 180/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0133 - mse: 0.0112 - val_loss: 0.0728 - val_mse: 0.0707
# Epoch 181/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0116 - mse: 0.0095 - val_loss: 0.0787 - val_mse: 0.0766
# Epoch 182/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0123 - mse: 0.0102 - val_loss: 0.0722 - val_mse: 0.0701
# Epoch 183/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0118 - mse: 0.0097 - val_loss: 0.0770 - val_mse: 0.0749
# Epoch 184/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0147 - mse: 0.0127 - val_loss: 0.0772 - val_mse: 0.0752
# Epoch 185/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0162 - mse: 0.0142 - val_loss: 0.0766 - val_mse: 0.0745
# Epoch 186/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0158 - mse: 0.0137 - val_loss: 0.0622 - val_mse: 0.0602
# Epoch 187/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0126 - mse: 0.0106 - val_loss: 0.0713 - val_mse: 0.0693
# Epoch 188/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0126 - mse: 0.0106 - val_loss: 0.0642 - val_mse: 0.0621
# Epoch 189/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0110 - mse: 0.0089 - val_loss: 0.0721 - val_mse: 0.0701
# Epoch 190/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0106 - mse: 0.0086 - val_loss: 0.0821 - val_mse: 0.0801
# Epoch 191/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0101 - mse: 0.0081 - val_loss: 0.0810 - val_mse: 0.0790
# Epoch 192/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0100 - mse: 0.0080 - val_loss: 0.0770 - val_mse: 0.0750
# Epoch 193/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0101 - mse: 0.0081 - val_loss: 0.0781 - val_mse: 0.0761
# Epoch 194/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0094 - mse: 0.0074 - val_loss: 0.0796 - val_mse: 0.0776
# Epoch 195/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0093 - mse: 0.0073 - val_loss: 0.0778 - val_mse: 0.0758
# Epoch 196/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0163 - mse: 0.0143 - val_loss: 0.0689 - val_mse: 0.0670
# Epoch 197/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0138 - mse: 0.0119 - val_loss: 0.0850 - val_mse: 0.0831
# Epoch 198/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0171 - mse: 0.0151 - val_loss: 0.0695 - val_mse: 0.0675
# Epoch 199/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0122 - mse: 0.0102 - val_loss: 0.0668 - val_mse: 0.0649
# Epoch 200/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0105 - mse: 0.0085 - val_loss: 0.0804 - val_mse: 0.0784
# Epoch 201/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0104 - mse: 0.0085 - val_loss: 0.0833 - val_mse: 0.0813
# Epoch 202/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0087 - mse: 0.0068 - val_loss: 0.0760 - val_mse: 0.0741
# Epoch 203/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0096 - mse: 0.0077 - val_loss: 0.0879 - val_mse: 0.0860
# Epoch 204/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0088 - mse: 0.0069 - val_loss: 0.0805 - val_mse: 0.0785
# Epoch 205/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0090 - mse: 0.0071 - val_loss: 0.0863 - val_mse: 0.0844
# Epoch 206/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0091 - mse: 0.0071 - val_loss: 0.0865 - val_mse: 0.0846
# Epoch 207/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0076 - mse: 0.0057 - val_loss: 0.0886 - val_mse: 0.0867
# Epoch 208/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0072 - mse: 0.0053 - val_loss: 0.0801 - val_mse: 0.0781
# Epoch 209/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0073 - mse: 0.0054 - val_loss: 0.0912 - val_mse: 0.0893
# Epoch 210/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0075 - mse: 0.0057 - val_loss: 0.0896 - val_mse: 0.0877
# Epoch 211/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0077 - mse: 0.0058 - val_loss: 0.0843 - val_mse: 0.0825
# Epoch 212/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0077 - mse: 0.0058 - val_loss: 0.0832 - val_mse: 0.0813
# Epoch 213/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0063 - mse: 0.0044 - val_loss: 0.0813 - val_mse: 0.0795
# Epoch 214/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0065 - mse: 0.0046 - val_loss: 0.0862 - val_mse: 0.0843
# Epoch 215/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0068 - mse: 0.0049 - val_loss: 0.0776 - val_mse: 0.0758
# Epoch 216/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0078 - mse: 0.0060 - val_loss: 0.0944 - val_mse: 0.0926
# Epoch 217/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0191 - mse: 0.0172 - val_loss: 0.0804 - val_mse: 0.0786
# Epoch 218/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0160 - mse: 0.0141 - val_loss: 0.0737 - val_mse: 0.0719
# Epoch 219/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0119 - mse: 0.0101 - val_loss: 0.0807 - val_mse: 0.0788
# Epoch 220/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0088 - mse: 0.0069 - val_loss: 0.0847 - val_mse: 0.0829
# Epoch 221/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0071 - mse: 0.0053 - val_loss: 0.0877 - val_mse: 0.0859
# Epoch 222/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0068 - mse: 0.0050 - val_loss: 0.0907 - val_mse: 0.0889
# Epoch 223/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0071 - mse: 0.0053 - val_loss: 0.0767 - val_mse: 0.0749
# Epoch 224/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0065 - mse: 0.0047 - val_loss: 0.0898 - val_mse: 0.0880
# Epoch 225/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0069 - mse: 0.0051 - val_loss: 0.0974 - val_mse: 0.0956
# Epoch 226/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0076 - mse: 0.0058 - val_loss: 0.0793 - val_mse: 0.0775
# Epoch 227/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0065 - mse: 0.0047 - val_loss: 0.0838 - val_mse: 0.0820
# Epoch 228/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0064 - mse: 0.0046 - val_loss: 0.0979 - val_mse: 0.0961
# Epoch 229/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0068 - mse: 0.0050 - val_loss: 0.0954 - val_mse: 0.0937
# Epoch 230/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0064 - mse: 0.0046 - val_loss: 0.0925 - val_mse: 0.0907
# Epoch 231/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0071 - mse: 0.0054 - val_loss: 0.0919 - val_mse: 0.0902
# Epoch 232/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0075 - mse: 0.0058 - val_loss: 0.0848 - val_mse: 0.0831
# Epoch 233/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0095 - mse: 0.0077 - val_loss: 0.0942 - val_mse: 0.0924
# Epoch 234/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0100 - mse: 0.0083 - val_loss: 0.1000 - val_mse: 0.0983
# Epoch 235/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0070 - mse: 0.0053 - val_loss: 0.0832 - val_mse: 0.0815
# Epoch 236/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0062 - mse: 0.0045 - val_loss: 0.0928 - val_mse: 0.0910
# Epoch 237/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0079 - mse: 0.0062 - val_loss: 0.0985 - val_mse: 0.0968
# Epoch 238/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0071 - mse: 0.0054 - val_loss: 0.0855 - val_mse: 0.0838
# Epoch 239/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0071 - mse: 0.0054 - val_loss: 0.0960 - val_mse: 0.0943
# Epoch 240/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0083 - mse: 0.0066 - val_loss: 0.0892 - val_mse: 0.0875
# Epoch 241/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0057 - mse: 0.0040 - val_loss: 0.0944 - val_mse: 0.0927
# Epoch 242/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0055 - mse: 0.0038 - val_loss: 0.1040 - val_mse: 0.1023
# Epoch 243/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0046 - mse: 0.0029 - val_loss: 0.0959 - val_mse: 0.0942
# Epoch 244/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0053 - mse: 0.0036 - val_loss: 0.0952 - val_mse: 0.0935
# Epoch 245/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0043 - mse: 0.0026 - val_loss: 0.0962 - val_mse: 0.0945
# Epoch 246/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0043 - mse: 0.0026 - val_loss: 0.0947 - val_mse: 0.0931
# Epoch 247/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0053 - mse: 0.0036 - val_loss: 0.0976 - val_mse: 0.0959
# Epoch 248/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0050 - mse: 0.0034 - val_loss: 0.1002 - val_mse: 0.0986
# Epoch 249/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0047 - mse: 0.0030 - val_loss: 0.0951 - val_mse: 0.0934
# Epoch 250/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0039 - mse: 0.0023 - val_loss: 0.0937 - val_mse: 0.0921
# Epoch 251/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0036 - mse: 0.0020 - val_loss: 0.1013 - val_mse: 0.0997
# Epoch 252/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0040 - mse: 0.0024 - val_loss: 0.0960 - val_mse: 0.0943
# Epoch 253/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0035 - mse: 0.0019 - val_loss: 0.1038 - val_mse: 0.1022
# Epoch 254/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0035 - mse: 0.0019 - val_loss: 0.1018 - val_mse: 0.1002
# Epoch 255/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0036 - mse: 0.0020 - val_loss: 0.1043 - val_mse: 0.1027
# Epoch 256/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0040 - mse: 0.0024 - val_loss: 0.1009 - val_mse: 0.0993
# Epoch 257/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0035 - mse: 0.0018 - val_loss: 0.0995 - val_mse: 0.0979
# Epoch 258/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0036 - mse: 0.0020 - val_loss: 0.1067 - val_mse: 0.1051
# Epoch 259/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0038 - mse: 0.0022 - val_loss: 0.1044 - val_mse: 0.1028
# Epoch 260/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0033 - mse: 0.0017 - val_loss: 0.1018 - val_mse: 0.1002
# Epoch 261/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0030 - mse: 0.0014 - val_loss: 0.1039 - val_mse: 0.1023
# Epoch 262/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0035 - mse: 0.0019 - val_loss: 0.1104 - val_mse: 0.1088
# Epoch 263/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0036 - mse: 0.0020 - val_loss: 0.0970 - val_mse: 0.0954
# Epoch 264/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0032 - mse: 0.0017 - val_loss: 0.0993 - val_mse: 0.0977
# Epoch 265/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0033 - mse: 0.0017 - val_loss: 0.1026 - val_mse: 0.1010
# Epoch 266/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0029 - mse: 0.0013 - val_loss: 0.1031 - val_mse: 0.1015
# Epoch 267/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0028 - mse: 0.0013 - val_loss: 0.1062 - val_mse: 0.1047
# Epoch 268/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0027 - mse: 0.0012 - val_loss: 0.1045 - val_mse: 0.1030
# Epoch 269/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0028 - mse: 0.0013 - val_loss: 0.1041 - val_mse: 0.1026
# Epoch 270/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0038 - mse: 0.0022 - val_loss: 0.1092 - val_mse: 0.1077
# Epoch 271/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0029 - mse: 0.0014 - val_loss: 0.1082 - val_mse: 0.1067
# Epoch 272/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0028 - mse: 0.0012 - val_loss: 0.0994 - val_mse: 0.0979
# Epoch 273/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0026 - mse: 0.0011 - val_loss: 0.1093 - val_mse: 0.1078
# Epoch 274/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0024 - mse: 9.1636e-04 - val_loss: 0.0978 - val_mse: 0.0963
# Epoch 275/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0027 - mse: 0.0012 - val_loss: 0.1038 - val_mse: 0.1023
# Epoch 276/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0033 - mse: 0.0018 - val_loss: 0.1002 - val_mse: 0.0987
# Epoch 277/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0029 - mse: 0.0014 - val_loss: 0.1042 - val_mse: 0.1027
# Epoch 278/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0036 - mse: 0.0021 - val_loss: 0.1004 - val_mse: 0.0990
# Epoch 279/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0033 - mse: 0.0019 - val_loss: 0.1077 - val_mse: 0.1062
# Epoch 280/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0033 - mse: 0.0018 - val_loss: 0.0942 - val_mse: 0.0927
# Epoch 281/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0027 - mse: 0.0013 - val_loss: 0.1128 - val_mse: 0.1113
# Epoch 282/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0024 - mse: 0.0010 - val_loss: 0.1026 - val_mse: 0.1011
# Epoch 283/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0025 - mse: 0.0010 - val_loss: 0.1090 - val_mse: 0.1076
# Epoch 284/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0023 - mse: 9.1483e-04 - val_loss: 0.1075 - val_mse: 0.1061
# Epoch 285/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0022 - mse: 7.3022e-04 - val_loss: 0.1055 - val_mse: 0.1041
# Epoch 286/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0031 - mse: 0.0017 - val_loss: 0.1038 - val_mse: 0.1024
# Epoch 287/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0026 - mse: 0.0012 - val_loss: 0.1037 - val_mse: 0.1022
# Epoch 288/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0033 - mse: 0.0019 - val_loss: 0.1060 - val_mse: 0.1046
# Epoch 289/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0045 - mse: 0.0031 - val_loss: 0.0942 - val_mse: 0.0928
# Epoch 290/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0044 - mse: 0.0030 - val_loss: 0.1028 - val_mse: 0.1015
# Epoch 291/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0049 - mse: 0.0035 - val_loss: 0.0943 - val_mse: 0.0930
# Epoch 292/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0040 - mse: 0.0027 - val_loss: 0.0988 - val_mse: 0.0974
# Epoch 293/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0038 - mse: 0.0024 - val_loss: 0.1025 - val_mse: 0.1011
# Epoch 294/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0044 - mse: 0.0030 - val_loss: 0.0967 - val_mse: 0.0953
# Epoch 295/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0034 - mse: 0.0021 - val_loss: 0.1033 - val_mse: 0.1019
# Epoch 296/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0039 - mse: 0.0025 - val_loss: 0.1155 - val_mse: 0.1142
# Epoch 297/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0044 - mse: 0.0030 - val_loss: 0.0973 - val_mse: 0.0959
# Epoch 298/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0038 - mse: 0.0025 - val_loss: 0.1142 - val_mse: 0.1129
# Epoch 299/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0039 - mse: 0.0026 - val_loss: 0.1045 - val_mse: 0.1032
# Epoch 300/300
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0032 - mse: 0.0019 - val_loss: 0.0988 - val_mse: 0.0975
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 2s 376ms/step
# %RMSE: 903.6367322190516
# %MAE: 749.0491271437472

# %%
n_steps_s = 12

model_args_s = [
    {'layer': 'Input', 'units': (n_steps_s, 3), 'args': {}},
    {'layer': 'LSTM', 'units':32, 'args': {'return_sequences': True, 'use_cudnn': False}},
    {'layer': 'LSTM', 'units':16, 'args': {'return_sequences': False, 'use_cudnn': False}},
    {'layer': 'Dense', 'units': 1, 'args': {}},
]

compile_args_s = {
    'optimizer': 'adam',
    'loss': 'mse',
    'metrics': ['mse'],
}

training_args_s = {
    'epochs': 150,
    'batch_size': 16,
    'validation_split': 0.15,
    'callbacks': [EarlyStopping(patience=20, restore_best_weights=True)],
    'verbose': 1
}

ad_s = train_model(
    target_column=target,
    date_col='date',
    train_column='seasonal',
    n_steps=n_steps_s,
    training_args=training_args_s,
    model_args=model_args_s,
    compile_args=compile_args_s
)
# Out:
# Index(['date', 'seasonal', 'trend', 'resid', 'observed', 'weights', 'rt'], dtype='object')
# X shape: (768, 12, 3)
# y shape: (768,)
# Epoch 1/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - loss: 0.5449 - mse: 0.5449 - val_loss: 0.1730 - val_mse: 0.1730
# Epoch 2/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1270 - mse: 0.1270 - val_loss: 0.1042 - val_mse: 0.1042
# Epoch 3/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0942 - mse: 0.0942 - val_loss: 0.0799 - val_mse: 0.0799
# Epoch 4/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0760 - mse: 0.0760 - val_loss: 0.0647 - val_mse: 0.0647
# Epoch 5/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0664 - mse: 0.0664 - val_loss: 0.0570 - val_mse: 0.0570
# Epoch 6/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0562 - mse: 0.0562 - val_loss: 0.0511 - val_mse: 0.0511
# Epoch 7/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0513 - mse: 0.0513 - val_loss: 0.0457 - val_mse: 0.0457
# Epoch 8/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0471 - mse: 0.0471 - val_loss: 0.0441 - val_mse: 0.0441
# Epoch 9/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0433 - mse: 0.0433 - val_loss: 0.0518 - val_mse: 0.0518
# Epoch 10/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0421 - mse: 0.0421 - val_loss: 0.0384 - val_mse: 0.0384
# Epoch 11/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.0345 - mse: 0.0345 - val_loss: 0.0318 - val_mse: 0.0318
# Epoch 12/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.
150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.4230e-15 - mse: 7.4230e-15 - val_loss: 8.0561e-15 - val_mse: 8.0561e-15
# Epoch 136/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.7252e-15 - mse: 6.7252e-15 - val_loss: 7.2960e-15 - val_mse: 7.2960e-15
# Epoch 137/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.5868e-15 - mse: 7.5868e-15 - val_loss: 7.9173e-15 - val_mse: 7.9173e-15
# Epoch 138/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0247e-14 - mse: 1.0247e-14 - val_loss: 4.1591e-15 - val_mse: 4.1591e-15
# Epoch 139/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.3034e-15 - mse: 9.3034e-15 - val_loss: 4.4286e-15 - val_mse: 4.4286e-15
# Epoch 140/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.5716e-15 - mse: 9.5716e-15 - val_loss: 1.3705e-14 - val_mse: 1.3705e-14
# Epoch 141/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.3927e-15 - mse: 7.3927e-15 - val_loss: 8.7969e-15 - val_mse: 8.7969e-15
# Epoch 142/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0325e-14 - mse: 1.0325e-14 - val_loss: 4.7681e-15 - val_mse: 4.7681e-15
# Epoch 143/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.9717e-15 - mse: 6.9717e-15 - val_loss: 4.4217e-15 - val_mse: 4.4217e-15
# Epoch 144/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 5.9549e-15 - mse: 5.9549e-15 - val_loss: 9.6077e-15 - val_mse: 9.6077e-15
# Epoch 145/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 6.7104e-15 - mse: 6.7104e-15 - val_loss: 1.1083e-14 - val_mse: 1.1083e-14
# Epoch 146/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.5618e-15 - mse: 8.5618e-15 - val_loss: 1.1205e-14 - val_mse: 1.1205e-14
# Epoch 147/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.6030e-15 - mse: 8.6030e-15 - val_loss: 7.3707e-15 - val_mse: 7.3707e-15
# Epoch 148/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.6297e-15 - mse: 8.6297e-15 - val_loss: 7.4091e-15 - val_mse: 7.4091e-15
# Epoch 149/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0610e-14 - mse: 1.0610e-14 - val_loss: 8.3656e-15 - val_mse: 8.3656e-15
# Epoch 150/150
# 37/37 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2523e-14 - mse: 1.2523e-14 - val_loss: 7.6819e-15 - val_mse: 7.6819e-15
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7a42a8981750> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 1s 558ms/stepWARNING:tensorflow:6 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7a42a8981750> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 263ms/step
# %RMSE: 0.0006686306652312014
# %MAE: 0.0005408035212701117

# %%
n_steps_o = 24

model_args_o = [
    {'layer': 'Input', 'units': (n_steps_o, 3), 'args': {}},
    {'layer': 'LSTM', 'units':32, 'args': {'return_sequences': False, 'use_cudnn': False}},
    {'layer': 'Dense', 'units': 1, 'args': {}},
]

compile_args_o = {
    'optimizer': 'adam',
    'loss': 'mse',
    'metrics': ['mse'],
}

training_args_o = {
    'epochs': 150,
    'batch_size': 24,
    'validation_split': 0.1,
    'callbacks': [EarlyStopping(patience=20, restore_best_weights=True)],
    'verbose': 0
}

ad_o = train_model(
    target_column=target,
    date_col='date',
    train_column='observed',
    n_steps=n_steps_o,
    training_args=training_args_o,
    model_args=model_args_o,
    compile_args=compile_args_o
)
# Out:
# Index(['date', 'seasonal', 'trend', 'resid', 'observed', 'weights', 'rt'], dtype='object')
# X shape: (756, 24, 3)
# y shape: (756,)
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# %RMSE: 5526.957625874
# %MAE: 4320.922295419793

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

series = ad_o.df.set_index('date')['observed']

# División manual
train = series[:'2016-08']  # hasta diciembre 2020
test = series['2016-09':]   # desde enero 2021

# Ajustar solo con train
model = SARIMAX(series, order=(1,1,1), seasonal_order=(1,1,1,12))
result = model.fit()

# Predecir en conjunto de prueba (in-sample)
start = test.index[0]
end = test.index[-1]
pred_test = result.predict(start=start, end=end)

# Calcular métricas
rmse = np.sqrt(mean_squared_error(test, pred_test))
mae = mean_absolute_error(test, pred_test)
print("%RMSE:", rmse * 100)
print("%MAE:", mae * 100)

# (Opcional) Predecir pasos futuros después de test
# forecast = result.get_forecast(steps=24)
# pred_future = forecast.predicted_mean
# pred_ci = forecast.conf_int()

# Graficar
plt.figure(figsize=(12,6))
plt.plot(pred_test.index, test, label='Real')
plt.plot(pred_test.index, pred_test, label='Predicción Test')
plt.legend()
plt.show()


forecast = result.get_forecast(steps=24)
pred_future = forecast.predicted_mean
pred_ci = forecast.conf_int()


plt.figure(figsize=(12,6))
plt.plot(series.index, series, label='Real')
plt.plot(pred_future.index, pred_future.values, label='Forecast', color='green')
plt.title(f"ARIMA Forecast {forecast_steps} pasos")
plt.legend()
plt.grid()
plt.show()
# Out:
# /usr/local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.46037D+00    |proj g|=  8.70097D-02
#
# At iterate    5    f=  5.39485D+00    |proj g|=  6.24758D-02
#
# At iterate   10    f=  5.32919D+00    |proj g|=  8.85051D-02
#
# At iterate   15    f=  5.26163D+00    |proj g|=  6.16260D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     19     26      1     0     0   3.676D-05   5.262D+00
#   F =   5.2615912467991235
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# %RMSE: 4489.0795213636575
# %MAE: 3240.424729009537

# %%
from statsmodels.tsa.arima.model import ARIMA
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Tu serie mensual
series = ad_o.df.set_index('date')['observed']

# División manual en train/test
train = series[:'2016-08']
test = series['2016-09':]

# Ajustar modelo ARIMA solo con train
# order = (p,d,q) -> ajusta según ACF/PACF o prueba heurística
model = ARIMA(series, order=(1,1,1))
result = model.fit()

# Predicción en el conjunto de prueba
pred_test = result.predict(start=test.index[0], end=test.index[-1], dynamic=False)

# Métricas
rmse = np.sqrt(mean_squared_error(test, pred_test))
mae = mean_absolute_error(test, pred_test)
print("%RMSE:", rmse * 100)
print("%MAE:", mae * 100)

# Graficar real vs predicción test
plt.figure(figsize=(12,6))
plt.plot(pred_test.index, test, label='Real')
plt.plot(pred_test.index, pred_test, label='Predicción Test', color='red')
plt.title("Predicción ARIMA Test")
plt.xlabel("Fecha")
plt.ylabel('Valor')
plt.legend()
plt.grid()
plt.show()

# Predicción de pasos futuros (out-of-sample)
forecast_steps = 24
forecast = result.get_forecast(steps=forecast_steps)
pred_future = forecast.predicted_mean
pred_ci = forecast.conf_int()

plt.figure(figsize=(12,6))
plt.plot(series.index, series, label='Real')
plt.plot(pred_future.index, pred_future.values, label='Forecast', color='green')
plt.title(f"ARIMA Forecast {forecast_steps} pasos")
plt.legend()
plt.grid()
plt.show()
# Out:
# %RMSE: 5466.959188190914
# %MAE: 4574.652430871273
# /usr/local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt

# Tomar la longitud mínima entre los arrays para que coincidan
min_len = min(
    len(ad_r._true_rescaled),
    len(ad_t._true_rescaled),
    len(ad_s._true_rescaled),
    len(pred_test.values)
)

# Convertir todo a 1D
r_true = ad_r._true_rescaled[-min_len:].flatten()
t_true = ad_t._true_rescaled[-min_len:].flatten()
s_true = ad_s._true_rescaled[-min_len:].flatten()

s_pred = ad_s._pred_rescaled[-min_len:].flatten()
t_pred = ad_t._pred_rescaled[-min_len:].flatten()
r_pred = pred_test.values[-min_len:].flatten()  # SARIMA trend o residual según tu modelo

# Sumar elemento a elemento
true_rescaled = r_true + t_true + s_true
pred_rescaled = r_pred + t_pred + s_pred

# Calcular métricas
rmse = np.sqrt(mean_squared_error(true_rescaled, pred_rescaled))
mae = mean_absolute_error(true_rescaled, pred_rescaled)
print("%RMSE:", rmse * 100)
print("%MAE:", mae * 100)

# Fechas
dates = ad_t._test_dates[-min_len:]

# Graficar
plt.figure(figsize=(14,5))
plt.plot(dates, true_rescaled, label="Real", alpha=0.5)
plt.plot(dates, pred_rescaled, label="Predicción", color="red", linewidth=2)
plt.title("Predicción LSTM + SARIMA (Trend + Seasonal + Residual)")
plt.xlabel(ad_t._date_col)
plt.ylabel(ad_t._target_col)
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()
# Out:
# %RMSE: 3268.1549800178323
# %MAE: 2306.380842225001

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# Encontrar la longitud mínima entre las predicciones verdaderas de los modelos
min_len = min(
    len(ad_r._true_rescaled),
    len(ad_t._true_rescaled),
    len(ad_s._true_rescaled)
)

# Recortar las verdaderas y predichas para que tengan la misma longitud (solo trend + seasonal)
true_rescaled = (
    ad_t._true_rescaled[-min_len:]
    + ad_s._true_rescaled[-min_len:]
    + ad_r._true_rescaled[-min_len:]
)

pred_rescaled = (
    ad_t._pred_rescaled[-min_len:]
    + ad_s._pred_rescaled[-min_len:]
    + ad_r._pred_rescaled[-min_len:]
)

# Aplanar los arrays para matplotlib
true_rescaled = true_rescaled.flatten()
pred_rescaled = pred_rescaled.flatten()

# Calcular métricas
rmse = np.sqrt(mean_squared_error(true_rescaled, pred_rescaled))
mae = mean_absolute_error(true_rescaled, pred_rescaled)
print("%RMSE:", rmse * 100)
print("%MAE:", mae * 100)

# Usar las fechas del modelo trend para el eje x, recortadas al mismo rango
dates = ad_t._test_dates[-min_len:]

# Graficar
plt.figure(figsize=(14,5))
plt.plot(dates, true_rescaled, label="Real", alpha=0.5)
plt.plot(dates, pred_rescaled, label="Predicción", color="red", linewidth=2)
plt.title("Predicción LSTM (Trend + Seasonal)")
plt.xlabel(ad_t._date_col)
plt.ylabel(ad_t._target_col)
plt.legend()
plt.grid()
plt.tight_layout()
plt.show()
# Out:
# %RMSE: 3268.4372394195007
# %MAE: 2478.593288722791

# %%
import matplotlib.pyplot as plt
import pandas as pd
def build_dates(year):
    return [f'{year}{month}01' if month >= 10 else f'{year}0{month}01' for month in range(1, 13)]
dates_input = build_dates(2023)
dates_input = dates_input + build_dates(2024)
predicts = []
predicts1 = []
for date in dates_input:
    _predict = ad_r.predict_for_date(date)
    _predict += ad_t.predict_for_date(date)
    _predict += ad_s.predict_for_date(date)
    predicts.append(_predict)

    _predict = ad_o.predict_for_date(date)
    predicts1.append(_predict)

forecast = result.get_forecast(steps=24)
pred_future = forecast.predicted_mean.values
pred_ci = forecast.conf_int()
plt.figure(figsize=(14,5))
plt.plot(pd.to_datetime(dates_input, format='%Y%m%d'), predicts, label="Predict S+T+R", color='white', linewidth=2)
plt.plot(pd.to_datetime(dates_input, format='%Y%m%d'), predicts1, label="Predict Obs", color='green', linewidth=1)
plt.plot(pd.to_datetime(dates_input, format='%Y%m%d'), pred_future, label="SARIMA", color='red', linewidth=3)
#plt.plot(ad_r.df['date'], ad_r.df['observed'], label="Real", color="red", linewidth=2)
plt.title("Predicción LSTM de " + target)
plt.xlabel("Fecha")
plt.ylabel(target)
plt.legend()
plt.grid()
plt.tight_layout()
